# %%
import pandas as pd
import numpy as np

# %%
bc = pd.read_csv("Breast_cancer.csv")
bc.head(40)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# 5     843786         M       12.450         15.70           82.57      477.1
# 6     844359         M       18.250         19.98          119.60     1040.0
# 7   84458202         M       13.710         20.83           90.20      577.9
# 8     844981         M       13.000         21.82           87.50      519.8
# 9   84501001         M       12.460         24.04           83.97      475.9
# 10    845636         M       16.020         23.24          102.70      797.8
# ...

# %%
bc.shape
# Out:
# (569, 33)

# %%
bc.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
bc['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
bc_dict = {'M':0,'B':1}
bc['diagnosis'] = bc['diagnosis'].map(bc_dict)

# %%
bc.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
bc = bc.drop(['id','Unnamed: 32'],axis=1)
bc.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
for feature in bc.columns:
    plt.scatter(bc[feature],bc['diagnosis'])
    plt.xlabel(feature)
    plt.show()

# %%
for feature in bc:
    data=bc.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
for feature in bc.columns[1:]:
    data = bc.copy()
    plt.boxplot(data=data,x=feature)
    plt.xlabel(feature)
    plt.show()

# %%
for feature in bc.columns:
    bc[feature]=bc[feature]**(1/1.2)

# %%
'''
for feature in bc.columns:
    IQR= bc[feature].quantile(0.75) - bc[feature].quantile(0.25)
    
    lower_bridge = bc[feature].quantile(0.25)-(IQR*1.5)
    upper_bridge = bc[feature].quantile(0.75)+(IQR*1.5)
    
    lower_bridge3 = bc[feature].quantile(0.25)-(IQR*3)
    upper_bridge3 = bc[feature].quantile(0.75)+(IQR*3)
    
    
    bc.loc[bc[feature]<=lower_bridge,feature] = lower_bridge
    bc.loc[bc[feature]>=upper_bridge,feature] = upper_bridge
'''
# Out:
# '\nfor feature in bc.columns:\n    IQR= bc[feature].quantile(0.75) - bc[feature].quantile(0.25)\n    \n    lower_bridge = bc[feature].quantile(0.25)-(IQR*1.5)\n    upper_bridge = bc[feature].quantile(0.75)+(IQR*1.5)\n    \n    lower_bridge3 = bc[feature].quantile(0.25)-(IQR*3)\n    upper_bridge3 = bc[feature].quantile(0.75)+(IQR*3)\n    \n    \n    bc.loc[bc[feature]<=lower_bridge,feature] = lower_bridge\n    bc.loc[bc[feature]>=upper_bridge,feature] = upper_bridge\n'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

#get correlations of each features in dataset
corrmat = bc.corr()

top_corr_features = corrmat.index
plt.figure(figsize=(20,20))

#plot heat map
g=sns.heatmap(bc[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
X = bc.iloc[:,1:]
y = bc.iloc[:,0]

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor(random_state=0)
model.fit(X,y)
# Out:
# ExtraTreesRegressor(random_state=0)

# %%
model.feature_importances_
# Out:
# array([0.02605643, 0.01887407, 0.04326523, 0.06924869, 0.00609991,
#        0.00410237, 0.04970665, 0.10625507, 0.00385601, 0.00267435,
#        0.00691235, 0.0038334 , 0.00712843, 0.01675139, 0.00408866,
#        0.00500405, 0.00376855, 0.0036124 , 0.0045584 , 0.00386408,
#        0.10472739, 0.02504805, 0.12020107, 0.11078684, 0.01497308,
#        0.0126809 , 0.03846333, 0.16883794, 0.0074714 , 0.00714953])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error

# %%
lg = LogisticRegression(max_iter=10000)
lg.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred = lg.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score,roc_auc_score

print("MSE:",mean_squared_error(y_test,y_pred))

print(confusion_matrix(y_test,y_pred)*100)
print(accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
# Out:
# MSE: 0.03508771929824561
# [[2000  200]
#  [   0 3500]]
# 96.49122807017544
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.91      0.95        22
#          1.0       0.95      1.00      0.97        35
#
#     accuracy                           0.96        57
#    macro avg       0.97      0.95      0.96        57
# weighted avg       0.97      0.96      0.96        57

# %% [markdown]
# #### Cross Validation

# %%
from sklearn.model_selection import KFold
import numpy as np
from sklearn.model_selection import GridSearchCV

# %%
grid = {'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv = KFold(n_splits=5, random_state = None, shuffle=False)

# %%
clf = GridSearchCV(lg,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(X_train_scaled,y_train)
# Out:
# C:\Users\bhargavi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\bhargavi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\bhargavi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %%
y_pred = clf.predict(X_test_scaled)
print("MSE:",mean_squared_error(y_test,y_pred))

print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
# Out:
# MSE: 0.0
# [[22  0]
#  [ 0 35]]
# 100.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        22
#          1.0       1.00      1.00      1.00        35
#
#     accuracy                           1.00        57
#    macro avg       1.00      1.00      1.00        57
# weighted avg       1.00      1.00      1.00        57

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
bc_rf = RandomForestClassifier(criterion='entropy')   
bc_rf.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
y_predict = bc_rf.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score,roc_auc_score

print("MSE:",mean_squared_error(y_test,y_pred))

print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
# Out:
# MSE: 0.0
# [[22  0]
#  [ 0 35]]
# 100.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        22
#          1.0       1.00      1.00      1.00        35
#
#     accuracy                           1.00        57
#    macro avg       1.00      1.00      1.00        57
# weighted avg       1.00      1.00      1.00        57
